# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "latin-1")

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.groupby('Area').sum("Y2017")
# Out:
#                              Area Code  Item Code  Element Code       Y2014  \
# Area
# Algeria                           5252    3532053       5017927   313375.33
# Angola                            9968    3819908       5515088   208584.42
# Benin                            68105    3453692       4852820   118050.79
# Botswana                         27560    3704902       5259784    22339.92
# Burkina Faso                    328297    3778795       5431243   105051.33
# Cabo Verde                       44100    3396746       4787751    14576.94
# Cameroon                         46720    3916078       5663196   217630.28
# Central African Republic         49728    3607546       5069094    28739.02
# Chad                             52377    3606529       5108355    65940.17
# Comoros                           2025     124514        241681       32.00
# Congo                            64998    3792029       5445560    38699.26
# ...

# %%
df.groupby(['Area', 'Element'])['Y2014'].sum()
# Out:
# Area      Element
# Algeria   Domestic supply quantity                  83755.94
#           Export Quantity                            1328.64
#           Fat supply quantity (g/capita/day)          320.19
#           Feed                                       9656.04
#           Food                                      60582.69
#                                                       ...
# Zimbabwe  Protein supply quantity (g/capita/day)      184.23
#           Residuals                                  -252.00
#           Seed                                        144.00
#           Stock Variation                            -644.00
#           Total Population - Both sexes             13587.00
# Name: Y2014, Length: 803, dtype: float64

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df[df.Y2014.isnull()]
# Out:
#        Area Code      Area  Item Code                 Item  Element Code  \
# 46             4   Algeria       2805    Rice and products          5911
# 61             4   Algeria       2513  Barley and products          5911
# 88             4   Algeria       2515     Rye and products          5611
# 100            4   Algeria       2516                 Oats          5911
# 183            4   Algeria       2533       Sweet potatoes          5911
# ...          ...       ...        ...                  ...           ...
# 60362        181  Zimbabwe       2616            Plantains           664
# 60363        181  Zimbabwe       2616            Plantains           674
# 60364        181  Zimbabwe       2616            Plantains           684
# 60623        181  Zimbabwe       2732   Mutton & Goat Meat          5911
# 60646        181  Zimbabwe       2734         Poultry Meat          5911
#
#                                       Element             Unit  Y2014  Y2015  \
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
df["Area"].nunique()
# Out:
# 49
